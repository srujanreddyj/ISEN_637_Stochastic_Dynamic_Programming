# %%
import pandas as pd
import numpy as np
import random as rnd
import scipy.stats as stats
import scipy.optimize as opt
import json as json
import matplotlib as mpl
from math import exp
from matplotlib import pyplot as plt
from IPython.core.pylabtools import figsize
from IPython.display import display
from IPython.core.display import HTML

# %%
f = open('C:\\Users\\jsruj\\Desktop\\637_Project\\a530875.asc', 'r') # 'r' = read
data = np.genfromtxt(f, delimiter='\n')

# %%
data1 = np.ndarray.tolist(data)

# %%
data1[0]
# Out:
# 5297.0

# %%
data1[-1]

# %%
data1.pop()
# Out:
# nan

# %%
len(data1)
# Out:
# 4736

# %%
first_bus = data1[0]
second_bus = first_bus + 1
second_bus_index = data1.index(second_bus)
second_bus_index
# Out:
# 128

# %%
nb_data_points = second_bus_index - 1
nb_buses = len(data1)/(nb_data_points+1)
nb_buses
# Out:
# 128

# %%
tab_data = [data1[i:i+nb_data_points+1] for i in range(0, len(data1), (nb_data_points+1))]

# %%
df_data = pd.DataFrame.from_records(tab_data)

# %%
df_data.rename(columns={0:'bus_no.',1:'month_purchased',2:'year_purchased',3:'month of first replace',
                        4:'year of first replace',5:'odomoter at replace',6:'month of second replace',
                        7:'year of second replace',8:'odomoter at replace',9:'month odomoter data began',
                        10:'year odomoter data began',11:'odomoter reading'})
# Out:
#     bus_no.  month_purchased  year_purchased  month of first replace  \
# 0    5297.0              8.0            75.0                     4.0
# 1    5298.0              8.0            75.0                     0.0
# 2    5299.0              8.0            75.0                     9.0
# 3    5300.0              8.0            75.0                     9.0
# 4    5301.0              8.0            75.0                    12.0
# 5    5302.0              8.0            75.0                     2.0
# 6    5303.0              8.0            75.0                    12.0
# 7    5304.0              8.0            75.0                     2.0
# 8    5305.0              7.0            75.0                     6.0
# 9    5306.0              8.0            75.0                     7.0
# 10   5307.0              8.0            75.0                     4.0
# 11   5308.0              7.0            75.0                     1.0
# 12   5309.0              8.0            75.0                     9.0
# ...

# %%
def g(theta1):
    u_n
    alpha
    N
    G = (1/N) * (np.sum((J(x1)-J(x2))/alpha)*u_n)
    return G

# %%
def J(theta1):
    np.sum(np.log(prob_dist))

# %%
def prob_dist(theta1):
    a = np.exp(Q(s,a))
    b = np.sum(np.exp(Q(s,a)))
    c = a/b
    return c

# %%
def Q(s,a):
